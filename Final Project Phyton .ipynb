# %%
import pandas as pd
import numpy as np

location = ("Financial Sample.xlsx")
df = pd.read_excel(location)
df
# Out:
#               Segment                   Country      Product Discount Band  \
# 0          Government                    Mexico      Bicycle          None
# 1          Enterprise                    France      Bicycle          None
# 2    Channel Partners                   Germany      Bicycle          None
# 3          Government                   Germany      Bicycle          None
# 4    Channel Partners                   Germany      Bicycle          None
# 5          Enterprise  United States of America      Bicycle          None
# 6          Enterprise                    Canada      Bicycle          None
# 7          Government                    France      Bicycle           Low
# 8          Government                    France      Bicycle           Low
# 9          Government                    Mexico      Bicycle           Low
# 10         Enterprise                    Canada      Bicycle           Low
# ...

# %%
df.replace('')
